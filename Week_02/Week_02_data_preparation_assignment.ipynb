# %%
import pandas as pd
import matplotlib.pyplot as plt

#Loading the dataset
form_data = pd.read_csv("form.csv")
print(form_data)
# Out:
#   birth_month       state   pet
# 0     January         NaN  Cats
# 1         JAN          CA  Cats
# 2        Sept      Hawaii   Dog
# 3     january          AK   Dog
# 4        July          RI  Cats
# 5   September  California  Cats
# 6       April          CA   Dog
# 7     January  California  Cats
# 8    November          FL   Dog
# 9    December     Florida  Cats

# %%
form_data['state'].value_counts().plot(kind='bar');
plt.show()

# %%
form_data['birth_month'].value_counts().plot(kind='bar');
plt.show()

# %% [markdown]
# My recommendation is that the month and state should be dropdowns just like the options for the pet type i.e. cats and dogs. This will ensure the uniform entries for the data analysis and visualization
