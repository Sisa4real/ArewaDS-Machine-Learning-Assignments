# %%
#Importing the required libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_mushrooms = pd.read_csv('mushrooms.csv')
data_mushrooms.head()
# Out:
#        class cap-shape cap-surface cap-color     bruises     odor  \
# 0  Poisonous    Convex      Smooth     Brown     Bruises  Pungent
# 1     Edible    Convex      Smooth    Yellow     Bruises   Almond
# 2     Edible      Bell      Smooth     White     Bruises    Anise
# 3  Poisonous    Convex       Scaly     White     Bruises  Pungent
# 4     Edible    Convex      Smooth     Green  No Bruises     None
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0            Free        Close    Narrow      Black  ...
# 1            Free        Close     Broad      Black  ...
# 2            Free        Close     Broad      Brown  ...
# 3            Free        Close    Narrow      Brown  ...
# 4            Free      Crowded     Broad      Black  ...
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                   Smooth                  White                  White
# 1                   Smooth                  White                  White
# ...

# %%
data_mushrooms.head()
# Out:
#        class cap-shape cap-surface cap-color     bruises     odor  \
# 0  Poisonous    Convex      Smooth     Brown     Bruises  Pungent
# 1     Edible    Convex      Smooth    Yellow     Bruises   Almond
# 2     Edible      Bell      Smooth     White     Bruises    Anise
# 3  Poisonous    Convex       Scaly     White     Bruises  Pungent
# 4     Edible    Convex      Smooth     Green  No Bruises     None
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0            Free        Close    Narrow      Black  ...
# 1            Free        Close     Broad      Black  ...
# 2            Free        Close     Broad      Brown  ...
# 3            Free        Close    Narrow      Brown  ...
# 4            Free      Crowded     Broad      Black  ...
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                   Smooth                  White                  White
# 1                   Smooth                  White                  White
# ...

# %%
data_mushrooms.tail()
# Out:
#           class cap-shape cap-surface cap-color     bruises   odor  \
# 8119     Edible   Knobbed      Smooth     Brown  No Bruises   None
# 8120     Edible    Convex      Smooth     Brown  No Bruises   None
# 8121     Edible      Flat      Smooth     Brown  No Bruises   None
# 8122  Poisonous   Knobbed       Scaly     Brown  No Bruises  Fishy
# 8123     Edible    Convex      Smooth     Brown  No Bruises   None
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# 8119        Attached        Close     Broad     Yellow  ...
# 8120        Attached        Close     Broad     Yellow  ...
# 8121        Attached        Close     Broad      Brown  ...
# 8122            Free        Close    Narrow       Buff  ...
# 8123        Attached        Close     Broad     Yellow  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 8119                   Smooth                 Orange                 Orange
# ...

# %%
data_mushrooms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
data_mushrooms.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
data_mushrooms.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
data_mushrooms.select_dtypes(["object"]).columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
cols = data_mushrooms.select_dtypes(["object"]).columns
data_mushrooms[cols] = data_mushrooms[cols].astype('category')

# %%
edibleclass=data_mushrooms.groupby(['class']).count()
edibleclass
# Out:
#            cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# class
# Edible          4208         4208       4208     4208  4208             4208
# Poisonous       3916         3916       3916     3916  3916             3916
#
#            gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# class                                                        ...
# Edible             4208       4208        4208         4208  ...
# Poisonous          3916       3916        3916         3916  ...
#
#            stalk-surface-below-ring  stalk-color-above-ring  \
# class
# Edible                         4208                    4208
# Poisonous                      3916                    3916
#
#            stalk-color-below-ring  veil-type  veil-color  ring-number  \
# class
# Edible                       4208       4208        4208         4208
# Poisonous                    3916       3916        3916         3916
#
# ...

# %%
data_mushrooms.head(10)
# Out:
#        class cap-shape cap-surface cap-color     bruises     odor  \
# 0  Poisonous    Convex      Smooth     Brown     Bruises  Pungent
# 1     Edible    Convex      Smooth    Yellow     Bruises   Almond
# 2     Edible      Bell      Smooth     White     Bruises    Anise
# 3  Poisonous    Convex       Scaly     White     Bruises  Pungent
# 4     Edible    Convex      Smooth     Green  No Bruises     None
# 5     Edible    Convex       Scaly    Yellow     Bruises   Almond
# 6     Edible      Bell      Smooth     White     Bruises   Almond
# 7     Edible      Bell       Scaly     White     Bruises    Anise
# 8  Poisonous    Convex       Scaly     White     Bruises  Pungent
# 9     Edible      Bell      Smooth    Yellow     Bruises   Almond
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0            Free        Close    Narrow      Black  ...
# 1            Free        Close     Broad      Black  ...
# 2            Free        Close     Broad      Brown  ...
# ...

# %% [markdown]
# # Pie

# %%
labels=['Edible','Poisonous']
plt.pie(edibleclass['population'],labels=labels,autopct='%.1f %%')
plt.title('Edible?')
plt.show()

# %% [markdown]
# # Donuts

# %%
habitat=data_mushrooms.groupby(['habitat']).count()

# %%
habitat.head()
# Out:
#          class  cap-shape  cap-surface  cap-color  bruises  odor  \
# habitat
# Grasses   2148       2148         2148       2148     2148  2148
# Leaves     832        832          832        832      832   832
# Meadows    292        292          292        292      292   292
# Paths     1144       1144         1144       1144     1144  1144
# Urban      368        368          368        368      368   368
#
#          gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# habitat                                                        ...
# Grasses             2148          2148       2148        2148  ...
# Leaves               832           832        832         832  ...
# Meadows              292           292        292         292  ...
# Paths               1144          1144       1144        1144  ...
# Urban                368           368        368         368  ...
#
#          stalk-surface-above-ring  stalk-surface-below-ring  \
# habitat
# ...

# %%
labels=['Grasses','Leaves','Meadows','Paths','Urban','Waste','Wood']

plt.pie(habitat['class'], labels=labels,
        autopct='%1.1f%%', pctdistance=0.85) 
center_circle = plt.Circle((0, 0), 0.50, fc='white')
fig = plt.gcf()

fig.gca().add_artist(center_circle)
  
plt.title('Mushroom Habitats')
  
plt.show()

# %% [markdown]
# # Waffles

# %%
capcolor=data_mushrooms.groupby(['cap-color']).count()

# %%
capcolor
# Out:
#            class  cap-shape  cap-surface  bruises  odor  gill-attachment  \
# cap-color
# Brown       2284       2284         2284     2284  2284             2284
# Buff         168        168          168      168   168              168
# Cinnamon      44         44           44       44    44               44
# Green       1856       1856         1856     1856  1856             1856
# Pink         144        144          144      144   144              144
# Purple        16         16           16       16    16               16
# Red         1500       1500         1500     1500  1500             1500
# White       1040       1040         1040     1040  1040             1040
# Yellow      1072       1072         1072     1072  1072             1072
#
#            gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# cap-color                                                    ...
# Brown              2284       2284        2284         2284  ...
# ...

# %%
data ={'color': ['brown', 'buff', 'cinnamon', 'green', 'pink', 'purple', 'red', 'white', 'yellow'],
    'amount': capcolor['class']
     }
  
df = pd.DataFrame(data)
  
fig = plt.figure(
    FigureClass = Waffle,
    rows = 100,
    values = df.amount,
    labels = list(df.color),
    figsize = (30,30),
    colors=["brown", "tan", "maroon", "green", "pink", "purple", "red", "whitesmoke", "yellow"],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 7>()
#       1 data ={'color': ['brown', 'buff', 'cinnamon', 'green', 'pink', 'purple', 'red', 'white', 'yellow'],
#       2     'amount': capcolor['class']
#       3      }
#       5 df = pd.DataFrame(data)
#       7 fig = plt.figure(
# ----> 8     FigureClass = Waffle,
#       9     rows = 100,
#      10     values = df.amount,
#      11     labels = list(df.color),
#      12     figsize = (30,30),
#      13     colors=["brown", "tan", "maroon", "green", "pink", "purple", "red", "whitesmoke", "yellow"],
#      14 )
#
# NameError: name 'Waffle' is not defined
